# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import Citipy
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# API Key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 1 | alice town
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | acajutla
# Processing Record 8 of Set 1 | rjukan
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | itarema
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | torbay
# Processing Record 13 of Set 1 | lata
# Processing Record 14 of Set 1 | dosso
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | cherskiy
# Processing Record 19 of Set 1 | verkhnyaya toyma
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 1 | sayyan
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | borzya
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | taltal
# Processing Record 27 of Set 1 | asau
# Processing Record 28 of Set 1 | alofi
# Processing Record 29 of Set 1 | kukmor
# Processing Record 30 of Set 1 | ostrovnoy
# Processing Record 31 of Set 1 | borovoy
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | moron
# Processing Record 34 of Set 1 | matara
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | qax
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | elda
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | belluno
# Processing Record 43 of Set 1 | acapulco
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | shingu
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | ostersund
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | nome
# Processing Record 5 of Set 2 | laguna
# Processing Record 6 of Set 2 | cockburn town
# Processing Record 7 of Set 2 | yarada
# Processing Record 8 of Set 2 | sitka
# Processing Record 9 of Set 2 | mandalgovi
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | lasa
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | aklavik
# Processing Record 14 of Set 2 | cove
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | dhidhdhoo
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | tiznit
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | flinders
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | marzuq
# Processing Record 23 of Set 2 | hofn
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | karasjok
# Processing Record 26 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | graaff-reinet
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | norman wells
# Processing Record 33 of Set 2 | mantua
# Processing Record 34 of Set 2 | muravlenko
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | westport
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | inirida
# Processing Record 40 of Set 2 | rio grande
# Processing Record 41 of Set 2 | oktyabrskiy
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | ixtapa
# Processing Record 47 of Set 2 | pochutla
# Processing Record 48 of Set 2 | qaqortoq
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | turkistan
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 3 | amarkantak
# Processing Record 4 of Set 3 | faya
# Processing Record 5 of Set 3 | hervey bay
# Processing Record 6 of Set 3 | port hardy
# Processing Record 7 of Set 3 | steinbach
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | naco
# Processing Record 10 of Set 3 | hualmay
# Processing Record 11 of Set 3 | middlebury
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | kerema
# Processing Record 14 of Set 3 | taloda
# Processing Record 15 of Set 3 | kapaa
# Processing Record 16 of Set 3 | calumboyan
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 3 | klaksvik
# Processing Record 21 of Set 3 | tankhoy
# Processing Record 22 of Set 3 | kununurra
# Processing Record 23 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 3 | bilibino
# Processing Record 25 of Set 3 | margate
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | jomalig
# City not found. Skipping...
# Processing Record 28 of Set 3 | vao
# Processing Record 29 of Set 3 | atar
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | carnarvon
# Processing Record 32 of Set 3 | shenxian
# Processing Record 33 of Set 3 | coquimbo
# Processing Record 34 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 3 | west wendover
# Processing Record 37 of Set 3 | saint-joseph
# Processing Record 38 of Set 3 | anadyr
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | kharp
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | tyler
# Processing Record 45 of Set 3 | buta
# Processing Record 46 of Set 3 | cape town
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | mazagao
# Processing Record 49 of Set 3 | kruisfontein
# Processing Record 50 of Set 3 | port elizabeth
# Processing Record 1 of Set 4 | havre-saint-pierre
# Processing Record 2 of Set 4 | souillac
# Processing Record 3 of Set 4 | yumen
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | phuket
# Processing Record 6 of Set 4 | bredasdorp
# Processing Record 7 of Set 4 | altar
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | colesberg
# Processing Record 10 of Set 4 | ust-nera
# Processing Record 11 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 4 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 13 of Set 4 | lahaina
# Processing Record 14 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 4 | tucupita
# Processing Record 16 of Set 4 | shakawe
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | los llanos de aridane
# Processing Record 19 of Set 4 | sarkand
# Processing Record 20 of Set 4 | bharatpur
# Processing Record 21 of Set 4 | bluff
# Processing Record 22 of Set 4 | nesterov
# Processing Record 23 of Set 4 | xiongzhou
# Processing Record 24 of Set 4 | comodoro rivadavia
# Processing Record 25 of Set 4 | christchurch
# Processing Record 26 of Set 4 | labytnangi
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | meulaboh
# Processing Record 30 of Set 4 | kostomuksha
# Processing Record 31 of Set 4 | gilazi
# City not found. Skipping...
# Processing Record 32 of Set 4 | altamira
# Processing Record 33 of Set 4 | muncar
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | villanueva de cordoba
# Processing Record 37 of Set 4 | perry
# Processing Record 38 of Set 4 | adiake
# Processing Record 39 of Set 4 | mar del plata
# Processing Record 40 of Set 4 | formosa do rio preto
# Processing Record 41 of Set 4 | imbituba
# Processing Record 42 of Set 4 | san patricio
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | taoudenni
# Processing Record 45 of Set 4 | bauchi
# Processing Record 46 of Set 4 | mbini
# Processing Record 47 of Set 4 | notse
# Processing Record 48 of Set 4 | woodward
# Processing Record 49 of Set 4 | yacuiba
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | ahipara
# Processing Record 3 of Set 5 | chumikan
# Processing Record 4 of Set 5 | the valley
# Processing Record 5 of Set 5 | askarovo
# Processing Record 6 of Set 5 | jiangyou
# Processing Record 7 of Set 5 | half moon bay
# Processing Record 8 of Set 5 | poya
# Processing Record 9 of Set 5 | galesong
# Processing Record 10 of Set 5 | mosetse
# Processing Record 11 of Set 5 | nuuk
# Processing Record 12 of Set 5 | butzow
# Processing Record 13 of Set 5 | bembibre
# Processing Record 14 of Set 5 | calabozo
# Processing Record 15 of Set 5 | petrovsk
# Processing Record 16 of Set 5 | clyde river
# Processing Record 17 of Set 5 | pacific grove
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | huarmey
# Processing Record 20 of Set 5 | javanrud
# Processing Record 21 of Set 5 | bentiu
# Processing Record 22 of Set 5 | edd
# Processing Record 23 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 5 | tura
# Processing Record 25 of Set 5 | kitimat
# Processing Record 26 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 5 | ancud
# Processing Record 28 of Set 5 | pangnirtung
# Processing Record 29 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 30 of Set 5 | avera
# Processing Record 31 of Set 5 | alyangula
# Processing Record 32 of Set 5 | inhambane
# Processing Record 33 of Set 5 | marsabit
# Processing Record 34 of Set 5 | monterey
# Processing Record 35 of Set 5 | karakol
# Processing Record 36 of Set 5 | akcaabat
# Processing Record 37 of Set 5 | byron bay
# Processing Record 38 of Set 5 | lengshuijiang
# Processing Record 39 of Set 5 | guider
# Processing Record 40 of Set 5 | hami
# Processing Record 41 of Set 5 | zhigalovo
# Processing Record 42 of Set 5 | stavern
# Processing Record 43 of Set 5 | limbang
# Processing Record 44 of Set 5 | rajapur
# Processing Record 45 of Set 5 | narsaq
# Processing Record 46 of Set 5 | geraldton
# Processing Record 47 of Set 5 | kampong thum
# Processing Record 48 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 5 | pousat
# City not found. Skipping...
# Processing Record 50 of Set 5 | cabo san lucas
# Processing Record 1 of Set 6 | husavik
# Processing Record 2 of Set 6 | port macquarie
# Processing Record 3 of Set 6 | kaka
# Processing Record 4 of Set 6 | pilar
# Processing Record 5 of Set 6 | suoyarvi
# Processing Record 6 of Set 6 | lagoa
# Processing Record 7 of Set 6 | coihaique
# Processing Record 8 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 6 | rizhao
# Processing Record 10 of Set 6 | santa marta
# Processing Record 11 of Set 6 | polazna
# Processing Record 12 of Set 6 | lakhimpur
# Processing Record 13 of Set 6 | eyl
# Processing Record 14 of Set 6 | jiayuguan
# Processing Record 15 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 6 | gushikawa
# Processing Record 17 of Set 6 | machali
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | vestmannaeyjar
# Processing Record 20 of Set 6 | cauquenes
# Processing Record 21 of Set 6 | beloha
# Processing Record 22 of Set 6 | adrar
# Processing Record 23 of Set 6 | orlik
# Processing Record 24 of Set 6 | faanui
# Processing Record 25 of Set 6 | mitsamiouli
# Processing Record 26 of Set 6 | bonfim
# Processing Record 27 of Set 6 | goderich
# Processing Record 28 of Set 6 | parauna
# Processing Record 29 of Set 6 | minna
# Processing Record 30 of Set 6 | palmer
# Processing Record 31 of Set 6 | canar
# Processing Record 32 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 6 | san policarpo
# Processing Record 34 of Set 6 | touros
# Processing Record 35 of Set 6 | bambous virieux
# Processing Record 36 of Set 6 | nanortalik
# Processing Record 37 of Set 6 | ippy
# Processing Record 38 of Set 6 | najran
# Processing Record 39 of Set 6 | talakan
# Processing Record 40 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 6 | ascoli piceno
# Processing Record 42 of Set 6 | tigzirt
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | ende
# Processing Record 45 of Set 6 | ust-kan
# Processing Record 46 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 6 | staraya toropa
# Processing Record 48 of Set 6 | lidkoping
# Processing Record 49 of Set 6 | saint-pierre
# Processing Record 50 of Set 6 | senanga
# Processing Record 1 of Set 7 | nakamura
# Processing Record 2 of Set 7 | bahia blanca
# Processing Record 3 of Set 7 | quatre cocos
# Processing Record 4 of Set 7 | nkhotakota
# Processing Record 5 of Set 7 | mutsu
# Processing Record 6 of Set 7 | longyearbyen
# Processing Record 7 of Set 7 | tuktoyaktuk
# Processing Record 8 of Set 7 | sao gabriel da cachoeira
# Processing Record 9 of Set 7 | mayo
# Processing Record 10 of Set 7 | heiloo
# Processing Record 11 of Set 7 | hohhot
# Processing Record 12 of Set 7 | port blair
# Processing Record 13 of Set 7 | dingle
# Processing Record 14 of Set 7 | saint simons
# Processing Record 15 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 7 | sharan
# Processing Record 17 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 7 | villazon
# Processing Record 19 of Set 7 | kungsbacka
# Processing Record 20 of Set 7 | lompoc
# Processing Record 21 of Set 7 | vila franca do campo
# Processing Record 22 of Set 7 | nhlangano
# Processing Record 23 of Set 7 | tiksi
# Processing Record 24 of Set 7 | birobidzhan
# Processing Record 25 of Set 7 | severo-kurilsk
# Processing Record 26 of Set 7 | cururupu
# Processing Record 27 of Set 7 | langsa
# Processing Record 28 of Set 7 | gwanda
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | grand gaube
# Processing Record 31 of Set 7 | chapais
# Processing Record 32 of Set 7 | baraya
# Processing Record 33 of Set 7 | moberly
# Processing Record 34 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 7 | ketchikan
# Processing Record 36 of Set 7 | saltillo
# Processing Record 37 of Set 7 | antofagasta
# Processing Record 38 of Set 7 | jalingo
# Processing Record 39 of Set 7 | saint anthony
# Processing Record 40 of Set 7 | toppenish
# Processing Record 41 of Set 7 | chihuahua
# Processing Record 42 of Set 7 | porto nacional
# Processing Record 43 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 7 | te anau
# Processing Record 45 of Set 7 | buin
# Processing Record 46 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 47 of Set 7 | egvekinot
# Processing Record 48 of Set 7 | dukat
# Processing Record 49 of Set 7 | rodrigues alves
# Processing Record 50 of Set 7 | ngunguru
# Processing Record 1 of Set 8 | williams lake
# Processing Record 2 of Set 8 | brae
# Processing Record 3 of Set 8 | wukari
# Processing Record 4 of Set 8 | roald
# Processing Record 5 of Set 8 | bonthe
# Processing Record 6 of Set 8 | gambela
# Processing Record 7 of Set 8 | ust-maya
# Processing Record 8 of Set 8 | sirsa
# Processing Record 9 of Set 8 | scottsbluff
# Processing Record 10 of Set 8 | shu
# Processing Record 11 of Set 8 | churachandpur
# Processing Record 12 of Set 8 | arman
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | manavalakurichi
# Processing Record 15 of Set 8 | portland
# Processing Record 16 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 8 | tamiahua
# Processing Record 18 of Set 8 | ebolowa
# Processing Record 19 of Set 8 | erzin
# Processing Record 20 of Set 8 | mahon
# Processing Record 21 of Set 8 | iqaluit
# Processing Record 22 of Set 8 | kochi
# Processing Record 23 of Set 8 | isangel
# Processing Record 24 of Set 8 | tikhvin
# Processing Record 25 of Set 8 | bahar
# Processing Record 26 of Set 8 | piranhas
# Processing Record 27 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 8 | ivanovka
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | poum
# Processing Record 31 of Set 8 | sabha
# Processing Record 32 of Set 8 | ukiah
# Processing Record 33 of Set 8 | verkhoyansk
# Processing Record 34 of Set 8 | muros
# Processing Record 35 of Set 8 | zagan
# Processing Record 36 of Set 8 | paray-le-monial
# Processing Record 37 of Set 8 | burgeo
# Processing Record 38 of Set 8 | chernyshevskiy
# Processing Record 39 of Set 8 | tautira
# Processing Record 40 of Set 8 | belmonte
# Processing Record 41 of Set 8 | kovdor
# Processing Record 42 of Set 8 | passy
# Processing Record 43 of Set 8 | vanderhoof
# Processing Record 44 of Set 8 | vardo
# Processing Record 45 of Set 8 | tynda
# Processing Record 46 of Set 8 | santa isabel do rio negro
# Processing Record 47 of Set 8 | juarez
# Processing Record 48 of Set 8 | bafq
# Processing Record 49 of Set 8 | turayf
# Processing Record 50 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 9 | awbari
# Processing Record 2 of Set 9 | sao joao da barra
# Processing Record 3 of Set 9 | ambilobe
# Processing Record 4 of Set 9 | balikpapan
# Processing Record 5 of Set 9 | north vernon
# Processing Record 6 of Set 9 | zhezkazgan
# Processing Record 7 of Set 9 | khani
# Processing Record 8 of Set 9 | magui
# City not found. Skipping...
# Processing Record 9 of Set 9 | moranbah
# Processing Record 10 of Set 9 | suao
# City not found. Skipping...
# Processing Record 11 of Set 9 | haines junction
# Processing Record 12 of Set 9 | mana
# Processing Record 13 of Set 9 | newport
# Processing Record 14 of Set 9 | nuevo progreso
# Processing Record 15 of Set 9 | takoradi
# Processing Record 16 of Set 9 | tilichiki
# Processing Record 17 of Set 9 | pavlovsk
# Processing Record 18 of Set 9 | kharabali
# Processing Record 19 of Set 9 | kampot
# Processing Record 20 of Set 9 | rafraf
# Processing Record 21 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 9 | yanam
# Processing Record 23 of Set 9 | suez
# Processing Record 24 of Set 9 | lavrentiya
# Processing Record 25 of Set 9 | manokwari
# Processing Record 26 of Set 9 | akropong
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | karratha
# Processing Record 29 of Set 9 | nouadhibou
# Processing Record 30 of Set 9 | krasnyy yar
# Processing Record 31 of Set 9 | boundiali
# Processing Record 32 of Set 9 | puerto escondido
# Processing Record 33 of Set 9 | tutoia
# Processing Record 34 of Set 9 | price
# Processing Record 35 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 9 | nagato
# Processing Record 37 of Set 9 | oranjestad
# Processing Record 38 of Set 9 | kabinda
# Processing Record 39 of Set 9 | sattahip
# Processing Record 40 of Set 9 | chowchilla
# Processing Record 41 of Set 9 | sisimiut
# Processing Record 42 of Set 9 | pirenopolis
# Processing Record 43 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 9 | burica
# City not found. Skipping...
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | willmar
# Processing Record 47 of Set 9 | urumqi
# Processing Record 48 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 9 | parras
# City not found. Skipping...
# Processing Record 50 of Set 9 | caravelas
# Processing Record 1 of Set 10 | pitimbu
# Processing Record 2 of Set 10 | renukut
# Processing Record 3 of Set 10 | lashio
# Processing Record 4 of Set 10 | vostok
# Processing Record 5 of Set 10 | amudat
# Processing Record 6 of Set 10 | mount isa
# Processing Record 7 of Set 10 | basoko
# Processing Record 8 of Set 10 | bubaque
# Processing Record 9 of Set 10 | qurayyat
# Processing Record 10 of Set 10 | council bluffs
# Processing Record 11 of Set 10 | hearst
# Processing Record 12 of Set 10 | trojes
# Processing Record 13 of Set 10 | vila velha
# Processing Record 14 of Set 10 | heinola
# Processing Record 15 of Set 10 | sioux lookout
# Processing Record 16 of Set 10 | viedma
# Processing Record 17 of Set 10 | seoul
# Processing Record 18 of Set 10 | salalah
# Processing Record 19 of Set 10 | san cristobal
# Processing Record 20 of Set 10 | cookeville
# Processing Record 21 of Set 10 | pokaran
# Processing Record 22 of Set 10 | caramay
# Processing Record 23 of Set 10 | almaznyy
# Processing Record 24 of Set 10 | nelson bay
# Processing Record 25 of Set 10 | surt
# Processing Record 26 of Set 10 | balas
# Processing Record 27 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 10 | nishihara
# Processing Record 29 of Set 10 | tatui
# Processing Record 30 of Set 10 | hovd
# Processing Record 31 of Set 10 | shiloh
# Processing Record 32 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 10 | east wenatchee
# Processing Record 34 of Set 10 | isla mujeres
# Processing Record 35 of Set 10 | nambucca heads
# Processing Record 36 of Set 10 | zharkent
# Processing Record 37 of Set 10 | gayny
# Processing Record 38 of Set 10 | mardan
# Processing Record 39 of Set 10 | ruteng
# Processing Record 40 of Set 10 | douglas
# Processing Record 41 of Set 10 | esso
# Processing Record 42 of Set 10 | dankov
# Processing Record 43 of Set 10 | high level
# Processing Record 44 of Set 10 | seymchan
# Processing Record 45 of Set 10 | tieling
# Processing Record 46 of Set 10 | oranjemund
# Processing Record 47 of Set 10 | aksarka
# Processing Record 48 of Set 10 | myingyan
# Processing Record 49 of Set 10 | solnechnyy
# Processing Record 50 of Set 10 | paris
# Processing Record 1 of Set 11 | japura
# Processing Record 2 of Set 11 | balapur
# Processing Record 3 of Set 11 | zheleznodorozhnyy
# Processing Record 4 of Set 11 | blagoyevo
# Processing Record 5 of Set 11 | necochea
# Processing Record 6 of Set 11 | davila
# Processing Record 7 of Set 11 | namibe
# Processing Record 8 of Set 11 | miguel hidalgo
# Processing Record 9 of Set 11 | yashkul
# Processing Record 10 of Set 11 | miri
# Processing Record 11 of Set 11 | kuching
# Processing Record 12 of Set 11 | ovalle
# Processing Record 13 of Set 11 | charters towers
# Processing Record 14 of Set 11 | wagar
# Processing Record 15 of Set 11 | sorong
# Processing Record 16 of Set 11 | selaphum
# Processing Record 17 of Set 11 | mmathubudukwane
# Processing Record 18 of Set 11 | luangwa
# Processing Record 19 of Set 11 | amahai
# Processing Record 20 of Set 11 | yulara
# Processing Record 21 of Set 11 | uyuni
# Processing Record 22 of Set 11 | doha
# Processing Record 23 of Set 11 | provideniya
# Processing Record 24 of Set 11 | potgietersrus
# City not found. Skipping...
# Processing Record 25 of Set 11 | radovitskiy
# Processing Record 26 of Set 11 | miraflores
# Processing Record 27 of Set 11 | dalianwan
# Processing Record 28 of Set 11 | axim
# Processing Record 29 of Set 11 | praia da vitoria
# Processing Record 30 of Set 11 | oussouye
# Processing Record 31 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 11 | olinda
# Processing Record 33 of Set 11 | arbuzynka
# Processing Record 34 of Set 11 | nalut
# Processing Record 35 of Set 11 | obregon
# Processing Record 36 of Set 11 | matrei
# City not found. Skipping...
# Processing Record 37 of Set 11 | marsh harbour
# Processing Record 38 of Set 11 | neiafu
# Processing Record 39 of Set 11 | ligayan
# Processing Record 40 of Set 11 | inuvik
# Processing Record 41 of Set 11 | balkanabat
# Processing Record 42 of Set 11 | puerto baquerizo moreno
# Processing Record 43 of Set 11 | krasnoarmeysk
# Processing Record 44 of Set 11 | ayyampettai
# Processing Record 45 of Set 11 | svetlaya
# Processing Record 46 of Set 11 | arlit
# Processing Record 47 of Set 11 | placerville
# Processing Record 48 of Set 11 | babstovo
# Processing Record 49 of Set 11 | naze
# Processing Record 50 of Set 11 | batagay-alyta
# Processing Record 1 of Set 12 | beauceville
# Processing Record 2 of Set 12 | garmsar
# Processing Record 3 of Set 12 | harper
# Processing Record 4 of Set 12 | kupang
# Processing Record 5 of Set 12 | nakhon phanom
# Processing Record 6 of Set 12 | abalak
# Processing Record 7 of Set 12 | pingliang
# Processing Record 8 of Set 12 | road town
# Processing Record 9 of Set 12 | guerrero negro
# Processing Record 10 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 12 | port-cartier
# Processing Record 12 of Set 12 | buala
# Processing Record 13 of Set 12 | mehamn
# Processing Record 14 of Set 12 | plaster rock
# Processing Record 15 of Set 12 | caledon east
# Processing Record 16 of Set 12 | iracoubo
# Processing Record 17 of Set 12 | mahanje
# Processing Record 18 of Set 12 | shizunai
# Processing Record 19 of Set 12 | kashi
# Processing Record 20 of Set 12 | okhotsk
# Processing Record 21 of Set 12 | lazaro cardenas
# Processing Record 22 of Set 12 | ginowan
# Processing Record 23 of Set 12 | magadan
# Processing Record 24 of Set 12 | rawson
# Processing Record 25 of Set 12 | dubbo
# Processing Record 26 of Set 12 | thinadhoo
# Processing Record 27 of Set 12 | boende
# Processing Record 28 of Set 12 | baiao
# Processing Record 29 of Set 12 | ojinaga
# Processing Record 30 of Set 12 | olafsvik
# Processing Record 31 of Set 12 | martapura
# Processing Record 32 of Set 12 | alcudia
# Processing Record 33 of Set 12 | ternate
# Processing Record 34 of Set 12 | edirne
# Processing Record 35 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 36 of Set 12 | tagusao
# Processing Record 37 of Set 12 | brownwood
# Processing Record 38 of Set 12 | camacha
# Processing Record 39 of Set 12 | batagay
# Processing Record 40 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 41 of Set 12 | general pico
# Processing Record 42 of Set 12 | kemijarvi
# Processing Record 43 of Set 12 | oriximina
# Processing Record 44 of Set 12 | kirakira
# Processing Record 45 of Set 12 | paraiso
# Processing Record 46 of Set 12 | bobcaygeon
# Processing Record 47 of Set 12 | abu kamal
# Processing Record 48 of Set 12 | banda aceh
# Processing Record 49 of Set 12 | clacton-on-sea
# Processing Record 50 of Set 12 | eureka
# Processing Record 1 of Set 13 | agua verde
# Processing Record 2 of Set 13 | kalmunai
# Processing Record 3 of Set 13 | sao felix do xingu
# Processing Record 4 of Set 13 | albuquerque
# Processing Record 5 of Set 13 | excelsior springs
# Processing Record 6 of Set 13 | dunmore town
# Processing Record 7 of Set 13 | mudgee
# Processing Record 8 of Set 13 | pyay
# Processing Record 9 of Set 13 | krasnyy kholm
# Processing Record 10 of Set 13 | sibolga
# Processing Record 11 of Set 13 | belomorsk
# Processing Record 12 of Set 13 | plettenberg bay
# Processing Record 13 of Set 13 | makakilo city
# Processing Record 14 of Set 13 | tiebissou
# Processing Record 15 of Set 13 | dickinson
# Processing Record 16 of Set 13 | sembe
# Processing Record 17 of Set 13 | sola
# Processing Record 18 of Set 13 | mindelo
# Processing Record 19 of Set 13 | presidencia roque saenz pena
# Processing Record 20 of Set 13 | kyaukse
# Processing Record 21 of Set 13 | tuy hoa
# Processing Record 22 of Set 13 | akyab
# Processing Record 23 of Set 13 | sao jose da coroa grande
# Processing Record 24 of Set 13 | spas-demensk
# Processing Record 25 of Set 13 | nurobod
# Processing Record 26 of Set 13 | rengasdengklok
# Processing Record 27 of Set 13 | marsa matruh
# Processing Record 28 of Set 13 | campbell river
# Processing Record 29 of Set 13 | amboasary
# Processing Record 30 of Set 13 | vila do maio
# Processing Record 31 of Set 13 | dovolnoye
# Processing Record 32 of Set 13 | wadi musa
# Processing Record 33 of Set 13 | nsunga
# Processing Record 34 of Set 13 | calamar
# Processing Record 35 of Set 13 | itoman
# Processing Record 36 of Set 13 | camargo
# Processing Record 37 of Set 13 | sao miguel do araguaia
# Processing Record 38 of Set 13 | seaford
# Processing Record 39 of Set 13 | la ronge
# Processing Record 40 of Set 13 | viru
# Processing Record 41 of Set 13 | yuzhnyy
# Processing Record 42 of Set 13 | san vicente
# Processing Record 43 of Set 13 | katete
# Processing Record 44 of Set 13 | foumban
# Processing Record 45 of Set 13 | fairbanks
# Processing Record 46 of Set 13 | rathdrum
# Processing Record 47 of Set 13 | harwich
# Processing Record 48 of Set 13 | zhigansk
# Processing Record 49 of Set 13 | dandong
# Processing Record 50 of Set 13 | coahuayana
# Processing Record 1 of Set 14 | carlyle
# Processing Record 2 of Set 14 | nisia floresta
# Processing Record 3 of Set 14 | alice springs
# Processing Record 4 of Set 14 | porto novo
# Processing Record 5 of Set 14 | labuhan
# Processing Record 6 of Set 14 | puerto leguizamo
# Processing Record 7 of Set 14 | abha
# Processing Record 8 of Set 14 | salinas
# Processing Record 9 of Set 14 | diamantino
# Processing Record 10 of Set 14 | wewak
# Processing Record 11 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 14 | kolpashevo
# Processing Record 13 of Set 14 | acuna
# City not found. Skipping...
# Processing Record 14 of Set 14 | amazar
# Processing Record 15 of Set 14 | nara
# Processing Record 16 of Set 14 | hambantota
# Processing Record 17 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 14 | eyrarbakki
# Processing Record 19 of Set 14 | berlevag
# Processing Record 20 of Set 14 | acari
# Processing Record 21 of Set 14 | charlestown
# Processing Record 22 of Set 14 | ovsyanka
# Processing Record 23 of Set 14 | yaan
# Processing Record 24 of Set 14 | buzmeyin
# Processing Record 25 of Set 14 | hiji
# Processing Record 26 of Set 14 | kyabe
# Processing Record 27 of Set 14 | piacabucu
# Processing Record 28 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 14 | yar-sale
# Processing Record 30 of Set 14 | bria
# Processing Record 31 of Set 14 | buloh kasap
# Processing Record 32 of Set 14 | marshalltown
# Processing Record 33 of Set 14 | tigil
# Processing Record 34 of Set 14 | myitkyina
# Processing Record 35 of Set 14 | prince rupert
# Processing Record 36 of Set 14 | nador
# Processing Record 37 of Set 14 | binzhou
# Processing Record 38 of Set 14 | bathsheba
# Processing Record 39 of Set 14 | kismayo
# Processing Record 40 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 41 of Set 14 | yerbogachen
# Processing Record 42 of Set 14 | bahia honda
# Processing Record 43 of Set 14 | jumla
# Processing Record 44 of Set 14 | brewster
# Processing Record 45 of Set 14 | stamsund
# City not found. Skipping...
# Processing Record 46 of Set 14 | juneau
# Processing Record 47 of Set 14 | ajdabiya
# Processing Record 48 of Set 14 | elko
# Processing Record 49 of Set 14 | nawada
# Processing Record 50 of Set 14 | bealanana
# Processing Record 1 of Set 15 | salaya
# Processing Record 2 of Set 15 | grand-santi
# Processing Record 3 of Set 15 | manta
# Processing Record 4 of Set 15 | auki
# Processing Record 5 of Set 15 | black diamond
# Processing Record 6 of Set 15 | murray bridge
# Processing Record 7 of Set 15 | brzeg
# Processing Record 8 of Set 15 | tual
# Processing Record 9 of Set 15 | gewane
# Processing Record 10 of Set 15 | bardiyah
# Processing Record 11 of Set 15 | sambava
# Processing Record 12 of Set 15 | pozo colorado
# Processing Record 13 of Set 15 | san andres
# Processing Record 14 of Set 15 | lagos
# Processing Record 15 of Set 15 | huilong
# Processing Record 16 of Set 15 | mitchell
# Processing Record 17 of Set 15 | mazamari
# Processing Record 18 of Set 15 | raahe
# Processing Record 19 of Set 15 | ranot
# Processing Record 20 of Set 15 | belyy yar
# Processing Record 21 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 15 | sherwood
# Processing Record 23 of Set 15 | mount gambier
# Processing Record 24 of Set 15 | dali
# Processing Record 25 of Set 15 | kangavar
# Processing Record 26 of Set 15 | dunedin
# Processing Record 27 of Set 15 | mwense
# Processing Record 28 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 29 of Set 15 | bridgetown
# Processing Record 30 of Set 15 | hopfgarten
# Processing Record 31 of Set 15 | bantogon
# Processing Record 32 of Set 15 | zhanaozen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a data frame from the data
city_data_df = pd.DataFrame(city_data)

# Create a new order to match the example shown
new_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_order]

#Save to new DataFrame
city_data_df.to_csv('WeatherPy_Database.csv')
